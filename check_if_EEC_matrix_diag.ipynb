# %%
using HDF5

N=15
a=1.0
l=0.1
mass=1.0
r1=1
r2=-1
#Measurement time
t1i = 0.0
t2i = 0.0
t1f = 3.0
t2f = 3.0
dt = 0.2

i=16
j=15

data = h5open("Z:/Energy Correlator/1d_EEC_data/EEC,N=$N,a=$a,l=$l,m=$mass,r1=$r1,r2=$r2,t1i=$t1i,t1f=$t1f,t2i=$t2i,t2f=$t2f,dt=$dt", "r")
println(real(data["MaEl"][i,j]))
println(real(data["MaEl"][j,i]))
close(data)
# Out:
# 0.0004380487737429859
# 0.00043737506952681735
